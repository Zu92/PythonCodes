# %%
import re
import random

def draw(turns,word):
    if turns == 9:
        print("9 turns left")
        print("  --------  ")
    if turns == 8:
        print("8 turns left")
        print("  --------  ")
        print("     O      ")
    if turns == 7:
        print("7 turns left")
        print("  --------  ")
        print("     O      ")
        print("     |      ")
    if turns == 6:
        print("6 turns left")
        print("  --------  ")
        print("     O      ")
        print("     |      ")
        print("    /       ")
    if turns == 5:
        print("5 turns left")
        print("  --------  ")
        print("     O      ")
        print("     |      ")
        print("    / \     ")
    if turns == 4:
        print("4 turns left")
        print("  --------  ")
        print("   \ O      ")
        print("     |      ")
        print("    / \     ")
    if turns == 3:
        print("3 turns left")
        print("  --------  ")
        print("   \ O /    ")
        print("     |      ")
        print("    / \     ")
    if turns == 2:
        print("2 turns left")
        print("  --------  ")
        print("   \ O /|   ")
        print("     |      ")
        print("    / \     ")
    if turns == 1:
        print("1 turns left")
        print("Last breaths counting, Take care!")
        print("  --------  ")
        print("   \ O_|/   ")
        print("     |      ")
        print("    / \     ")
    if turns == 0:
        print("You loose")
        print("You let a kind man die")
        print("  --------  ")
        print("     O_|    ")
        print("    /|\      ")
        print("    / \     ")
        print("PERDISTE, la Palabra era", word)

def hangman():
    word=random.choice(["ahorcado","estrella","sabotaje","sector","tornado","extravagante","flor"])
    validLetter="abcdefghijklmnopqrstuvwxyz"
    turns=10
    hideWord=[]
    for letter in word:
        hideWord.append("_")
    print (hideWord)
    tuns=10
    print()
    while turns>0:
        intent=input("Ingrese una letra: ")
        if intent in validLetter:
            if word.find(intent)==-1:
                turns=turns-1
            else:
                indexLetter=0
                for letter in word:
                    if intent==letter:
                        hideWord[indexLetter]=letter
                    indexLetter=indexLetter+1
            print(hideWord)
            draw(turns,word)
            validation=""
            if validation.join(hideWord)==word:
                print("Ganaste: La Palabra era ", word)
                turns=0
        else:
            print("Ingresa una letra correcta")

name = input("Enter your name")
print("Welcome" , name )
print("-------------------")
print("try to guess the word in less than 10 attempts")
hangman()
print("Do you want to play again?")
answer=input("Enter Y/N")
while answer in ("Y","y"):
    print("Lets play again" , name )
    hangman()
    print("Do you want to play again?")
    answer=input("Enter Y/N")
print("Goodbye", name)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-99ec088349fe> in <module>
#      90             print("Ingresa una letra correcta")
#      91
# ---> 92 name = input("Enter your name")
#      93 print("Welcome" , name )
#      94 print("-------------------")
#
# ~\Anaconda3\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#     858                 "raw_input was called, but this frontend does not support input requests."
#     859             )
# --> 860         return self._input_request(str(prompt),
#     861             self._parent_ident,
#     862             self._parent_header,
#
# ~\Anaconda3\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
#     903                 # re-raise KeyboardInterrupt, to truncate traceback
# ...
